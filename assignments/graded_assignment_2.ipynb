# %% [markdown]
# # FHNW Machine Learning - FS 2025

# %%
# DO NOT EDIT THIS CELL
# ADD ADDITIONAL IMOPRTS IN ASSIGNMENT CELLS

# Notebook configs
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # Bewertetes Aufgabenblatt 2
#
# **Ausgabe:** Dienstag, 6.5.2025
#
# **Abgabe:** Sonntag, 1.6.2025, 23:59 Uhr

# %% [markdown]
# ## Vorgaben zu Umsetzung und Abgabe
#
# - Der Code in diesem Notebook muss lauffähig sein bei Ausführung im Docker-Container zum Repo. Nur was durchläuft wird korrigiert.
# - Es darf kein Code ausgelagert werden, i.e. sämtlicher Code muss sich im Notebook befinden. Notebooks dürfen weder umbenannt werden, noch soll die Ordnerstruktur im Repo verändert werden.
# - Sämtliche Plots sind komplett beschriftet (Achsen, Labels, Überschrift, Colorbar, ..), so dass der Plot ohne den Code zu konsultieren, verstanden werden kann.
# - Als **Abgabe** zählt der letzte Commit vor Abgabetermin in Ihrem Fork des Repos.
# - **Löschen, kopieren, duplizieren, splitten und verschieben Sie die vorhandenen Zellen nicht. Für fehlende Antwortzellen gibt es keine Punkte.** Sie dürfen beliebig viele weitere Zellen hinzufügen (nur via **insert new cell**).
# - Laufzeit vom Notebook: Das Notebook sollte in weniger als einer Stunde ausgeführt werden können.
#
# Für die Erarbeitung der Lösung darf unter Studierenden zusammengearbeitet werden.
# Die Zusammenarbeit ist dabei aber auf konzeptionelle und algorithmische Fragen und Verständnisaspekte beschränkt.
#
# **Es darf kein Code oder Text kopiert werden, weder vom Internet noch von Mitstudierenden.**
# Beim Vorfinden von kopiertem Code werden alle Aufgaben von allen Beteiligten mit 0 Punkten bewertet.
#
#
# #### Python Module
#
# Neben den Python-Basismodulen dürfen Sie die folgenden Module immer benutzen: `numpy`, `pandas`, `matplotlib`, `seaborn`,  `tqdm` (für Progress-Bars).
#
# Sie dürfen auch generell [sklearn.preprocessing](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.preprocessing), [sklearn.model_selection](https://scikit-learn.org/stable/model_selection.html), [sklearn.pipeline](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.pipeline) und [sklearn.compose](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.compose) benutzen.
#
# Zusätzliche Module dürfen Sie nur verwenden wenn ausdrücklich erwähnt oder bereits vorgegeben in der Code-Cell.
#
# ### Bewertung
#
# Bewertet wird:
#
# - Vollständigkeit (Code, Text)
# - Korrektheit (Code, Text)
# - Implementation (z.B. Vektorisierung der Operationen, Scikit-Learn API, Visualisierungen, Lesbarkeit Code/Output)

# %% [markdown]
# ## Einleitung
#
# Die Schweizerische Post möchte die Sortierung ihrer Briefe automatisieren. Um die Briefe in einem ersten Schritt in die korrekten Verteilzentren für die Feinverteilung zu überführen, müssen die Postleitzahlen auf den Briefen und Paketen korrekt erkannt werden. Die Post möchte nun, dass du dabei hilfst, diese Aufgabe zu erledigen. Du bekommst dazu einen Datensatz mit hangeschriebenen Ziffern, die du in einer Machbarkeitsstudie erkennen sollst.
#
# Du kannst den Datensatz mit wie folgt laden:
#
# ```python
# data = np.load('postleitzahlen.npz')
# x_train, y_train, x_test, y_test = data['x_train'], data['y_train'], data['x_test'], data['y_test']
# ```
#
# Die Postleitzahlziffern sind als 28 x 28 Bilder in `x_train` und `x_test` abgelegt, die dazugehörenden Label finden sich in `y_train` und `y_test`.

# %% [markdown]
# ## Aufgabe 1 (4 Punkte)
#
# Lade den Datensatz der Postleitzahlen und erstelle einen Plot von 10 x 10 zufällig ausgewählten Ziffern.

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

os.chdir('graded_assignments/graded_assignment_2')

# Step 01: Datensatz laden
data = np.load('postleitzahlen.npz')
x_train, y_train, x_test, y_test = data['x_train'], data['y_train'], data['x_test'], data['y_test']

# (just for me to understand the data format)
# x_train[0] = 2D-Array: 28x28 Graustufenwerte
# y_train[0] = z.B. 7 (Ziffer auf dem Bild)

# Step 02: 100 zufällige Indizes aus dem Trainingsset auswählen
random_indices = np.random.choice(x_train.shape[0], size=100, replace=False)

# Step 3: 10x10 Plot vorbereiten
plt.figure(figsize=(10, 10))
for i, idx in enumerate(random_indices):
    plt.subplot(10, 10, i + 1)
    plt.imshow(x_train[idx], cmap='gray')
    plt.axis('off')
    plt.title(str(y_train[idx]), fontsize=8)

plt.tight_layout()
plt.show()
# Out:
# <Axes: >
# (np.float64(-0.5), np.float64(27.5), np.float64(27.5), np.float64(-0.5))
# Text(0.5, 1.0, '5')
# <Axes: >
# (np.float64(-0.5), np.float64(27.5), np.float64(27.5), np.float64(-0.5))
# Text(0.5, 1.0, '9')
# <Axes: >
# (np.float64(-0.5), np.float64(27.5), np.float64(27.5), np.float64(-0.5))
# Text(0.5, 1.0, '3')
# <Axes: >
# (np.float64(-0.5), np.float64(27.5), np.float64(27.5), np.float64(-0.5))
# Text(0.5, 1.0, '7')
# <Axes: >
# (np.float64(-0.5), np.float64(27.5), np.float64(27.5), np.float64(-0.5))
# Text(0.5, 1.0, '8')
# <Axes: >
# (np.float64(-0.5), np.float64(27.5), np.float64(27.5), np.float64(-0.5))
# Text(0.5, 1.0, '1')
# <Axes: >
# (np.float64(-0.5), np.float64(27.5), np.float64(27.5), np.float64(-0.5))
# Text(0.5, 1.0, '1')
# <Axes: >
# (np.float64(-0.5), np.float64(27.5), np.float64(27.5), np.float64(-0.5))
# Text(0.5, 1.0, '4')
# <Axes: >
# (np.float64(-0.5), np.float64(27.5), np.float64(27.5), np.float64(-0.5))
# Text(0.5, 1.0, '1')
# <Axes: >
# ...

# %% [markdown]
# Um was für ein Machine Learning-Problem handelt es sich hier? Was denkst du, wie gut kann dir dies gelingen?
#
# (Es folgt eine Textantwortzelle. Nicht löschen.)

# %% [markdown]
# Es handelt sich um ein überwacht lernendes Klassifikationsproblem, bei dem handgeschriebene Ziffern (0–9) anhand von 28×28 Pixel großen Graustufenbildern erkannt werden sollen. Solche Bildklassifikationen sind mit modernen ML-Methoden wie Convolutional Neural Networks (CNNs) sehr gut lösbar und können Genauigkeiten von über 98% erreichen.

# %% [markdown]
# ## Aufgabe 2 (7 Punkte)
#
# Wir möchten zuerst verstehen, wie komplex unser Datensatz wirklich ist und setzen dazu Principal Component Analysis (PCA) ein. Principal Component Analysis ist eine wichtige Methode zur Visualisierung und adaptiven Kompression von Daten.
#
# Andrew Ng hat dazu drei gute Videos gemacht, die PCA einführen und erklären: [Part 1](https://www.youtube.com/watch?v=5W7ugCeROEc), [Part 2](https://www.youtube.com/watch?v=mk-5P4sKP8s), [Part 3](https://www.youtube.com/watch?v=fGct-AcatTI ) .  Schau dir die Videos an!
#
# Du darfst in der Folge den PCA-Transformer von scikit-learn (`sklearn.decomposition.PCA`) verwenden.
#
# Führe PCA auf deinen Trainingsziffern aus und zeichne die kumulative Varianz der Principal Components als Funktion einer wachsenden Anzahl von Komponenten.
#
# Wähle nun die ersten `k` Komponenten so, dass dabei 95% der Varianz der Daten erhalten bleibt. Wieviele Komponenten brauchst du dazu?
#
# Zeichne diese `k` Komponenten als Bilder, wie die Beispielziffern aus Aufgabe 1.

# %%
# CODE ANTWORTZELLE

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# rescale images from image (28x28) to a vector
x_train_flat = x_train.reshape(x_train.shape[0], -1)

# data normalization / scaling
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train_flat)

pca = PCA()
x_pca = pca.fit_transform(x_train_scaled)

cumulative_variance = np.cumsum(pca.explained_variance_ratio_)

# visualisation
plt.figure(figsize=(10, 5))
plt.plot(cumulative_variance, marker='o', linestyle='--', color='r', label='Cumulative Variance')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Variance')
plt.grid(True)
plt.axhline(y=0.95, color='g', linestyle='--')
plt.title('Cumulative Variance of Principal Components')
plt.show()
# Out:
# Text(0.5, 0, 'Number of Principal Components')
# Text(0, 0.5, 'Cumulative Variance')
# Text(0.5, 1.0, 'Cumulative Variance of Principal Components')

# %% [markdown]
# Was lernst du aus dieser Analyse? Wie interpretierst du die ersten `k` Principal Components?
#
# (Es folgt eine Textantwortzelle. Nicht löschen.)

# %% [markdown]
# * Es reichen wenige Principal Components (ca. 50-200) um ein Grossteil der Varianz zu erklären
# * Danach flacht die Kurve deutlich ab... um die restliche Varianz erklären zu können werden einige Principal Components mehr gebraucht
# * Die ersten Hauptkomponenten erfassen die dominanten Strukturen in den Bildern -> horizontale/vertikale Linien, Rundungen, Kontraste. Sie verallgemeinern die Unterschiede zwischen den Ziffern. Spätere Komponenten modellieren feinere Details oder Rauschen.

# %% [markdown]
# ## Aufgabe 3 (4 Punkte)
#
# Projiziere deine Trainingsdaten nun auf die ersten beiden Principal Components und zeichne die Datenpunkte im resultierenden 2-dimensionalen Koordinatensystem. Füge den Datenpunkten dabei durch Farbkodierung das zugehörige Label hinzu.

# %%
pca_2d = PCA(n_components=2)
x_train_pca_2d = pca_2d.fit_transform(x_train_scaled)

plt.figure(figsize=(10, 10))
scatter = plt.scatter(
    x_train_pca_2d[:, 0],
    x_train_pca_2d[:, 1],
    c=y_train,
    cmap='tab10',
    alpha=0.6, s=15
)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('Principal Component Visualisation in a 2D space')
plt.grid(True)
plt.show()
# Out:
# Text(0.5, 0, 'Principal Component 1')
# Text(0, 0.5, 'Principal Component 2')
# Text(0.5, 1.0, 'Principal Component Visualisation in a 2D space')

# %% [markdown]
# Wie interpretierst du diesen Plot?
#
# (Es folgt eine Textantwortzelle. Nicht löschen.)

# %% [markdown]
# Der Plot zeigt, dass sich die handgeschriebenen Ziffern in zwei PCA-Komponenten teilweise clustern lassen. Einige Ziffern lassen sich gut voneinander trennen, andere überlappen stark – was zeigt, dass für bessere Trennung mehr Dimensionen oder komplexere
# Methoden nötig sind.

# %% [markdown]
# ## Aufgabe 4 (8 Punkte)
#
# Projiziere die Trainingsziffern nun auf die ersten `k` Komponenten.
#
# Verwende dann ein regularisiertes lineares Logistisches Regressionsmodell von scikit-learn, um das zugehörige Label vorherzusagen. Finde ein bestmögliches Modell auf den Trainingsdaten im Sinne der Overall Accuracy und messe diese auch auf den Testdaten.
#
# Zeichne die Confusion Matrix, auf dem Testset.
#
# Gib die Resultate übersichtlich mit `print`-Statements aus.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, ConfusionMatrixDisplay
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# 1. Daten vorbereiten
x_train_flat = x_train.reshape(x_train.shape[0], -1)
x_test_flat = x_test.reshape(x_test.shape[0], -1)

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train_flat)
x_test_scaled = scaler.transform(x_test_flat)

# 2. Finde k
pca_full = PCA()
pca_full.fit(x_train_scaled)
cumulative_variance = np.cumsum(pca_full.explained_variance_ratio_)
k = np.argmax(cumulative_variance >= 0.95) + 1
print(f"Anzahl Komponenten für 95% Varianz: {k}")

# 3. Projiziere auf die ersten k Komponenten
pca_k = PCA(n_components=k)
x_train_pca_k = pca_k.fit_transform(x_train_scaled)
x_test_pca_k = pca_k.transform(x_test_scaled)

# 4. Trainiere logistische Regression (mit Regularisierung, z.B. C=1.0 Standard)
log_reg = LogisticRegression(max_iter=1000)
log_reg.fit(x_train_pca_k, y_train)

# 5. Vorhersage & Accuracy
y_train_pred = log_reg.predict(x_train_pca_k)
y_test_pred = log_reg.predict(x_test_pca_k)

train_acc = accuracy_score(y_train, y_train_pred)
test_acc = accuracy_score(y_test, y_test_pred)

print(f"Train Accuracy: {train_acc:.4f}")
print(f"Test Accuracy:  {test_acc:.4f}")

# 6. Confusion Matrix
ConfusionMatrixDisplay.from_predictions(y_test, y_test_pred, cmap='Blues')
plt.title("Confusion Matrix on Test Set")
plt.grid(False)
plt.show()
# Out:
# PCA()
# Anzahl Komponenten für 95% Varianz: 331
# LogisticRegression(max_iter=1000)
# Train Accuracy: 0.9353
# Test Accuracy:  0.9262
# Text(0.5, 1.0, 'Confusion Matrix on Test Set')

# %% [markdown]
# Diskutiere dein Modellierungsergebnis.
#
# (Es folgt eine Textantwortzelle. Nicht löschen.)

# %% [markdown]
# ## Meine Auswertung
# - Die Bilddaten wurden auf 784 Dimensionen reduziert und mittels PCA auf **331 Hauptkomponenten** komprimiert (95 % Varianz).
# - Anschliessend wurde ein reguläres **Logistikmodell (C=1.0, max_iter=1000)** trainiert.
# - **Train Accuracy:** 0.9353
# - **Test Accuracy:** 0.9262
#
# ### Analyse der Confusion Matrix
#
# - Sehr gute Klassifikation für die Ziffern **0, 1, 6, 9** mit jeweils über 900 korrekten Vorhersagen.
# - Häufige Verwechslungen:
#   - **5 & 3, 6, 8**
#   - **8 & 3, 5, 9**
# - Fehler entstehen meist bei **ähnlich geformten Ziffern**.
#
# ### Fazit
#
# - Die PCA mit 331 Komponenten bewahrt den wesentlichen Informationsgehalt der Bilder.
# - Die logistische Regression ist **effizient, robust** und bietet eine **starke Baseline**.
# - Für nichtlineare Strukturen könnten komplexere Modelle wie MLPs sinnvoll sein.

# %%
# %%sql

# %% [markdown]
# ## Aufgabe 5 - Multi-Layer Perceptron (15 Punkte)
#
# Implementiere nun ein Multi-Layer Perceptron mit Sigmoid Aktivierungsfunktionen zur Multi-Klass Klassifikation.
#
# Dabei sollen mindestens die Architektur (# layers / units per layer), die Regularisierung ($\alpha$), die Learning Rate ($\eta$), und die Batch-Size konfigurierbar sein.
#
# Initialisiere die Gewichte zufällig mit kleinen Werten, z.B. aus dem Intervall $[-0.7, 0.7]$. Dabei sollst du sicherstellen, dass der Fit der Modelle reproduzierbar ist. Setze also _random seeds_ um die Initialisierung der Gewichte reproduzierbar zu machen [siehe numpy](https://numpy.org/doc/stable/reference/random/index.html#random-quick-start).
#
# Ergänze dazu die vorgegebene Klasse.
#
# #### Kostenfunktion
#
# Es soll folgende Kostenfunktion $J$ minimiert werden (_cross-entropy_ mit Regularisierung):
#
# \begin{align}
# J(\mathbf{w}) &= \frac{1}{N}\sum_{i=1}^{N} \sum_{k=1}^{K} \Big(- y_k^{(i)} \log \hat{y}_k^{(i)} \Big) + C \\
# C &= \frac{\alpha}{2} \sum_{l=1}^{L}\sum_{j=1}^{u^{(l)}} \sum_{i=1}^{u^{(l-1)}} (w^{(l)}_{ij})^2
# \end{align}
#
# #### Notation
#
# - $N$: Anzahl Datenpunkte
# - $L$: Anzahl Layer (ohne Input-Layer)
# - $K$: Anzahl Klassen
# - $p$: Anzahl Input Features
# - $\alpha$: Regularisierungsfaktor
# - $\mathbf{a}^{(l)}$ Aktivierungen im Layer $l$ (l=0 ist Input-Layer)
# - $\mathbf{z}^{(l)}$ pre-activations / logits im Layer $l$
# - $\mathbf{y}^{(i)} \in \{0, 1\}$: One-hot encoded Vektor mit Dimensionalität $\mathbb{R}^K$,  Eintrag 1 indiziert die Klassenzugehörigkeit
# - $\hat{y}_k^{(i)}$ Prediction für Klasse $k$, $P(Y=k| x^{(i)})$
# - $w^{(l)}_{ij}$: Gewicht / Parameter $ij$ von Layer $l$
# - $W^{(l)}$ Parameter von Layer $l$ mit $\in \mathbb{R}^{u^{(l-1)} \times u^{(l)}}$ oder mit Bias $\mathbb{R}^{(u^{(l-1)}+1) \times u^{(l)}}$
# - $u^{(l)}$: Anzahl Nodes (units) im Layer $l$, ohne Bias Node
# - $g()$: Aktivierungsfunktion
#
#
# #### Forward Pass
#
# Exemplarisch für einen Datenpunk $\mathbf{x}^{(i)}$. Wir nehmen an, dass der Bias als 1-er Spalte eingefügt wurde $x_0^{(i)}=1$.
#
# \begin{align*}
# \mathbf{a}^{(0)} &= \mathbf{x}^{(i)} \\
# \mathbf{z}^{(1)} &= \mathbf{a}^{(0)T}W^{(1)} \\
# \mathbf{a}^{(1)} &= g(\mathbf{z}^{(1)}) \\
# .. &= .. \\
# \mathbf{z}^{(l)} &= \mathbf{a}^{(l-1)T}W^{(l)} \\
# \mathbf{a}^{(l)} &= g(\mathbf{z}^{(l)}) \\
# .. &= .. \\
# \mathbf{\hat{y}}_k^{(i)} &= a_k^{(L)} \\
# g(\mathbf{z}^{(l)}) &=  \frac{1}{1+e^{-z^{(l)}}} & \text{Sigmoid Aktivierungsfunktion für Hidden-Layers } (l \lt L)  \\
# a_i^{(L)} &= \sigma(\mathbf{z}^{(L)})_i = \frac{e^{z_i}}{\sum_{j=1}^K e^{z_j}} & \text{ Softmax-Funktion for } l = L
# \end{align*}
#
# #### Backpropagation
#
# Backpropagation ist der zentrale Algorithmus beim Trainieren von Neuronalen Netzwerken um die partiellen Ableitung der Loss-Funktion bezüglich der Parameter zu berechnen. Dabei wird der Gradient der Loss-Funktion vom Output des Netzwerkes mit Hilfe der Kettenregel zurückpropagiert. Du sollst diesen Algorithmus anwenden, um alle $\frac{\partial J}{\partial \mathbf{w_{ij}^{(l)}}}$ zu bestimmen. Folgende Zusammenhänge sind hilfreich bei der Implementation:
#
#
# \begin{align*}
# \frac{\partial a^{(l)}}{\partial z^{(l)}} &= g(z^{(l)})(1 - g(z^{(l)})) = a^{(l)} \odot (1- a^{(l)}) & \text{for } l \lt L\\
# \frac{\partial z^{(l)}}{\partial a^{(l-1)}} &= W^{(l)} \\
# \frac{\partial z^{(l)}}{\partial W^{(l)}} &= a_i^{(l-1)}
# \end{align*}
#
#
# Man kann den Gradienten der Kostenfunktion bezüglich der Gewichte $W$ rekursiv bestimmen:
#
# \begin{align*}
# \frac{\partial J}{\partial \mathbf{z}^{(L)}} &= \delta^{(L)} = \mathbf{\hat{y}} - \mathbf{y} & \text{initialize back-prop with this}\\
# \delta^{(l)} &= \Big(\frac{\partial z^{(l+1)}}{\partial a^{(l)}} \delta^{(l+1)} \Big) \odot \frac{\partial a^{(l)}}{\partial z^{(l)}} & \text{iteratively calculate for the backprop-step, for } l \lt L \\
# \frac{\partial J}{\partial W^{(l)}} &=  \Big(\frac{\partial z^{(l)}}{\partial W^{(l)}}\Big)^T \delta^{(l)}  & \text{gradients for the weights, this is what we want!}
# \end{align*}
#
#
#
#
# Wenn du mehr dazu lesen möchtest, findest du weitere gute Herleitungen hier:
#
# - [CS229 Stanford](https://cs229.stanford.edu/notes2020spring/cs229-notes-deep_learning.pdf)
#
# Zum Thema Backpropagation gibt es ausserdem ausgezeichnete Videos:
#
# - [3Blue1Brown Video 1](https://youtu.be/IHZwWFHWa-w)
#
# - [3Blue1Brown Video 2](https://youtu.be/Ilg3gGewQ5U)
#
#
#
# #### Vektorisierung
#
# Wir können den Forward-Pass und die Backpropagation effizient berechnen, indem wir die Operationen vektorisieren. Wir berechnen die Aktivierungen direkt für alle Datenpunkte $N$. Die Bias-Vektoren $\mathbf{b}$ werden direkt in die Aktivierungs-Matrizen hinzugefügt. Auch die Backpropagation lässt sich vektorisieren, wir berechnen dann den durchschnittlichen Gradienten über alle Datenpunkte. Ohne Vektorisierung wird deine Implementation zu langsam sein. Hier der Ablauf für die Forward-Propagation:
#
#
# \begin{align*}
# \mathbf{X} & \in \mathbb{R}^{N \times (p + 1)} \\
# \mathbf{A}^{(l)} & \in \mathbb{R}^{N \times (u^{(l)} + 1)} \\
# \mathbf{Z}^{(l)} & \in \mathbb{R}^{N \times (u^{(l)})} \\
# \mathbf{W}^{(l)} & \in \mathbb{R}^{(u^{(l-1)} + 1) \times u^{(l)}} \\
# \mathbf{b}^{(l)} & \in \mathbb{R}^{u^{(l)} \times 1} \\
# \mathbf{Z}^{(1)} &= \mathbf{X} \mathbf{W}^{(1)} \\
# \mathbf{A}^{(1)} &= g( \mathbf{Z}^{(1)}) & \text{add bias node if necessary}\\
# ... \hspace{4pt} &= \hspace{4pt} ... \\
# \mathbf{A}^{(L)} &= g( \mathbf{Z}^{(L)}) & \text{no bias at output}\\
# \end{align*}

# %% [markdown]
# Folgende Grafik zeigt illustrativ die Struktur von einem MLP. Beachte auch die eingefügten Bias-Nodes (orange), die nur mit Neuronen im nächsten Layer verbunden sind.

# %%
from IPython.display import Image

Image(filename='./mlp.png')

# %%
import copy
from itertools import islice
from typing import List, Tuple, Union, Iterable

import numpy as np
from tqdm.notebook import tqdm

from sklearn.base import BaseEstimator
from sklearn.preprocessing import LabelBinarizer


class MLPClassifier(BaseEstimator):
    """ Multi-Layer Perceptron for Classifikation
    
        Args:
            num_nodes_per_layer: List with the number of nodes per layer
                 - including input-layer (features)
                 - no bias nodes should be included
                 - example: [10, 5, 2] -> 10 Features, 5 Nodes in 1st Hidden Layer, 2 Output Nodes
    
            lr: initial learning rate (float)
    
            alpha: L2 Regularization strength (float)
            
            batch_size: number of samples to use for one update 
                - set to None for batch gradient descent (all samples)
        
            max_num_steps: max number of steps (gradient updates)
            
            weights_init_range: Tuple of two floats. 
                - The interval on which the weights will be randomly initialized
                
            adaptive_lr_constant: Adpative learning rate constant
                - lr_new = lr * exp(-adaptive_lr_constant * step)
                - disable with 0.0
    
            min_lr: Minimum Learning Rate, relevant when using adaptive_lr_constant > 0.0
            
            random_seed: random seed for weights initialization (int)
    """

    def __init__(
            self,
            num_nodes_per_layer: List[int],
            lr: float = 0.01,
            alpha: float = 0.0,
            batch_size: Union[int, None] = None,
            max_num_steps: int = 1000,
            weights_init_range: Tuple[float, float] = (-0.7, 0.7),
            adaptive_lr_constant: float = 0.0,
            min_lr: float = 1e-4,
            random_seed: int = 123
    ):
        self.num_nodes_per_layer = num_nodes_per_layer
        self.lr = lr
        self.alpha = alpha
        self.batch_size = batch_size
        self.max_num_steps = max_num_steps
        self.weights_init_range = weights_init_range
        self.adaptive_lr_constant = adaptive_lr_constant
        self.min_lr = min_lr
        self.random_seed = random_seed
        self._initialize_weights()

    def _initialize_weights(self):
        """ Initialize Model-Parameters
        Example: num_nodes_per_layer = [3, 4, 2]
        W0.shape = (4,4)

        self.weights_ = [W0, W1, ..., Wn]
        W0 = 3 Input Features -> 4 Neuros from the Hidden Layer 1
        W1 = 4 Neurons of the Hidden Layer 1 to the 2 Output Neurons from the Output Layer
        W0 = [
                [w11, w12, w13, w14], -> Weights of the Input Feature 1 to the 4 Hidden Neurons
                [w21, w22, w23, w24], -> Weights of the Input Feature 2 to the 4 Hidden Neurons
                [w31, w32, w33, w34], -> Weights of the Input Feature 3 to the 4 Hidden Neurons
                [b1,  b2,  b3,  b4] -> Bias_weights for the 4 Hidden Neurons
             ]
        """

        np.random.seed(self.random_seed)
        self.weights_ = []
        for i in range(len(self.num_nodes_per_layer) - 1):
            input_size = self.num_nodes_per_layer[i] + 1  # Plus one because of the BIAS Adding
            output_size = self.num_nodes_per_layer[i + 1]
            low, high = self.weights_init_range
            W = np.random.uniform(low=low, high=high, size=(input_size, output_size))
            self.weights_.append(W)

    def forward(self, X: np.ndarray) -> List[np.ndarray]:
        """ forward pass - calculate all activations
            Args:
                X: Input-Activations [num_samples, num_features]

            Returns: List of Layer-Activations

            Example for X:
            2 Examples with each 3 features
            X = np.array([
                        [0.1, 0.2, 0.3], Example Data 1
                        [0.5, 0.6, 0.7] Example Data 2
                        ])

            Example of activations:
            num_nodes_per_layer = [3, 4, 2] and X from above

            activations = [
                            array([[0.1, 0.2, 0.3],
                                    [0.5, 0.6, 0.7]]), Input

                            array([[0.55, 0.48, 0.67, 0.62],
                                    [0.73, 0.59, 0.84, 0.77]]), Hidden Layer Versteckte Schicht

                            array([[0.61, 0.39],
                                    [0.22, 0.78]]) Softmax-Output
                            ]
        """
        activations = [X]
        A = X
        for i, W in enumerate(self.weights_):  # runs through every Wn
            A = np.hstack([A, np.ones(
                (A.shape[0], 1))])  # Adding the Bias -> Adds to every row at the right a 1
            Z = A @ W  # Matrix Multiplication
            if i < len(self.weights_) - 1:
                A = self.sigmoid(Z)
            else:
                A = self.softmax(Z)
            activations.append(A)
        return activations

    def backward(self, activations: List[np.ndarray], delta_upstream: np.ndarray) -> List[
        np.ndarray]:
        """ backward pass / backpropagation - Calculate partial derivatives of model weights
            Args:
                activations: List of Layer Activations, Output of forward()
        
                delta_upstream: Matrix with partial derivatives of Loss functions wrt. 
                    logits of last layer[num_samples, num_outputs]
    
            Returns: List of Layer-Gradients
            activations = [A0, A1, ..., An] etc.

        """
        gradients = []
        for i in reversed(range(len(
                self.weights_))):  # backwards from output layer towards input layer weights
            A_prev = np.hstack([activations[i], np.ones((activations[i].shape[0],
                                                         1))])  # gets corresponding Activation, for example, A0 if we are looking at W0

            # Compute the gradient of the weight matrix:
            # - First term: standard gradient from the chain rule (input.T @ delta)
            # - Second term: L2 regularization (applied to all weights except the bias row, which remains unregularized)
            # The result is the full weight gradient including regularization
            dW = A_prev.T @ delta_upstream + self.alpha * np.vstack(
                [self.weights_[i][:-1], np.zeros((1, self.weights_[i].shape[1]))])
            gradients.insert(0, dW)

            if i > 0:
                delta_upstream = (delta_upstream @ self.weights_[i][:-1].T) * (
                        activations[i] * (1 - activations[i]))
        return gradients

    def fit(self, X: np.ndarray, y: np.ndarray,
            X_val: Union[np.ndarray, None] = None,
            y_val: Union[np.ndarray, None] = None,
            validate_after_every_num_steps: int = 20) -> None:

        num_classes = np.unique(y).shape[0]
        lb = LabelBinarizer()
        y_encoded = lb.fit_transform(y)

        self.loss_curve_ = []

        for step in tqdm(range(self.max_num_steps)):
            lr = max(self.lr * np.exp(-self.adaptive_lr_constant * step), self.min_lr)
            batch_generator = self.generate_batches(X, y_encoded, self.batch_size)
            X_batch, y_batch = next(batch_generator)

            activations = self.forward(X_batch)
            y_pred = activations[-1]

            cost = self.calculate_cost(y_batch, y_pred)
            self.loss_curve_.append(cost)

            delta = self.calculate_gradient_of_cost_function(y_batch, y_pred)
            gradients = self.backward(activations, delta)

            for i in range(len(self.weights_)):
                self.weights_[i] -= lr * gradients[i]

            if X_val is not None and y_val is not None and step % validate_after_every_num_steps == 0:
                acc = self.score(X_val, y_val)
                print(f"Step {step}: validation accuracy {acc: .4f}")

        return self


    def calculate_cost(self, y_true: np.ndarray, y_pred: np.ndarray) -> float:
        """ Calculate Cross-Entropy cost """
        m = y_true.shape[0]
        eps = 1e-12 # Small constant to prevent log(0)
        cross_entropy = -np.sum(y_true * np.log(y_pred + eps)) / m
        l2_reg = self.alpha * sum(np.sum(W[:-1] ** 2) for W in self.weights_)
        return cross_entropy + l2_reg

    def calculate_gradient_of_cost_function(self, y_true: np.ndarray,
                                            y_pred: np.ndarray) -> np.ndarray:
        """ Calculate gradient of cost function w.r.t logits dJ/dZ """
        return (y_pred - y_true) / y_true.shape[0]

    def softmax(self, x: np.ndarray) -> np.ndarray:
        """ Softmax along last dimension: x is of shape [num_samples, num_classes] """
        x_shifted = x - np.max(x, axis=1, keepdims=True)
        exp_x = np.exp(x_shifted)
        return exp_x / np.sum(exp_x, axis=1, keepdims=True)

    def sigmoid(self, x: np.ndarray) -> np.ndarray:
        """ Sigmoid activation function """
        return 1 / (1 + np.exp(-x))

    def predict_proba(self, X: np.ndarray) -> np.ndarray:
        """ All class probabilities per sample
            -> input shape  [num_samples, num_features]
            -> output shape [num_samples, num_classes]
        """
        return self.forward(X)[-1]

    def predict(self, X: np.ndarray) -> np.ndarray:
        """ Return most likely class per sample
           -> input shape  [num_samples, num_features]
           -> output shape [num_samples, 1]
        """
        return np.argmax(self.predict_proba(X), axis=1)

    def score(self, X: np.ndarray, y: np.ndarray) -> np.ndarray:
        """ Calculate Accuracy """
        y_pred = self.predict(X)
        return np.mean(y_pred == y)

    def generate_batches(
            self, X: np.ndarray, y: np.ndarray,
            batch_size: Union[int, None],
            shuffle: bool = True) -> Iterable[Tuple[np.ndarray, np.ndarray]]:
        """ Generate batches of data [BATCH_SIZE, NUM_FEATURES]"""

        # Batch Gradient Descent
        if not batch_size:
            batch_size = X.shape[0]
            while True:
                yield X, y

        # Flexible Batch-Size that works with batch_size != None
        while True:
            # randomly shuffle input data
            shuffled_indices = np.arange(X.shape[0])
            if shuffle:
                np.random.shuffle(shuffled_indices)

            # iterate over batches
            iter_indices = np.arange(X.shape[0])
            slices = islice(iter_indices, 0, None, batch_size)

            # select batches
            for start_index in slices:
                indices_to_select = shuffled_indices[start_index: start_index + batch_size]
                yield X[indices_to_select, :], y[indices_to_select, :]

    def grad_check(
            self, X: np.ndarray, y: np.ndarray,
            epsilon: float = 0.0001,
            decimal: int = 3,
            verbose: bool = False) -> None:
        """Compare the gradient with finite differences around current point in parameter space
            Args:
                X, y: Data
                epsilon: step to take around current parameters
                decimal: verify equality if approximatino is within +- 1e-<decimal>
        """
        # calculate gradient
        activations = self.forward(X)
        y_hat = activations[-1]
        delta_upstream = self.calculate_gradient_of_cost_function(y, y_hat)
        gradients = self.backward(activations, delta_upstream)

        # approximate gradient
        gradients_approx = copy.deepcopy(gradients)
        original_layers = copy.deepcopy(self.weights_)

        # Iterate over each parameter of the network
        for i, weights in enumerate(self.weights_):
            for j, _ in enumerate(weights.flat):
                # generate copy of original parameters for modification
                modified_layers = copy.deepcopy(original_layers)

                # assign modified layers for use in other methods
                self.weights_ = modified_layers

                # J(theta + epsilon)
                modified_layers[i].flat[j] += epsilon
                y_hat = self.predict_proba(X)
                cost_plus_epsilon = self.calculate_cost(y, y_hat)

                # J(theta - epsilon)
                modified_layers[i].flat[j] -= 2 * epsilon
                y_hat = self.predict_proba(X)
                cost_minus_epsilon = self.calculate_cost(y, y_hat)

                # Approx gradient with:
                # (J(theta + epsilon) - J(theta - epsilon)) / (2 * epsilon)
                grad_approx = (
                        (cost_plus_epsilon - cost_minus_epsilon) /
                        (2 * epsilon))

                gradients_approx[i].flat[j] = grad_approx

        # reset layers attribute
        self.weights_ = copy.deepcopy(original_layers)

        # normalize gradients
        gradients_approx = [x / np.linalg.norm(x) for x in gradients_approx]
        gradients = [x / np.linalg.norm(x) for x in gradients]

        if verbose:
            print('approx : ', gradients_approx)
            print('calc : ', gradients)

        for approx, calculated in zip(gradients_approx, gradients):
            np.testing.assert_array_almost_equal(approx, calculated, decimal=decimal)
        print(f"Gradients within +- 1e-{decimal} of approximated gradient!")

# %% [markdown]
# Stelle bei der Implementierung der obigen Klasse sicher, dass die folgenden Tests keine Fehler erzeugen.
#
# Dies will aber nicht heissen, dass deine Umsetzung komplett korrekt ist. Es gibt noch weitere verborgene Tests, die zur Korrektur eingesetzt werden.
#
# Hinweis: Du kannst zusätzlich mit der Methode `grad_check()`, welche den Gradienten mit finiten Differenzen berechnet, die Implementation deiner Gradienten-Berechnung überprüfen.

# %%
# TESTS

def print_result(test_name, passed, expected, actual):
    status = "Passed" if passed else "Failed"


def test_weight_initialization_shapes():
    model = MLPClassifier([4, 5, 2], random_seed=42)
    model._initialize_weights()
    w0, w1 = model.weights_
    assert w0.shape == (5, 5), f"Expected (5, 5), got {w0.shape}"
    assert w1.shape == (6, 2), f"Expected (6, 2), got {w1.shape}"
    print("✓ test_weight_initialization_shapes passed.")


def test_forward_pass_output_shape():
    model = MLPClassifier([4, 5, 2], random_seed=42)
    model._initialize_weights()
    X = np.random.randn(5, 4)
    activations = model.forward(X)
    assert activations[-1].shape == (5, 2), f"Expected (5, 2), got {activations[-1].shape}"
    print("✓ test_forward_pass_output_shape passed.")


def test_softmax_output():
    model = MLPClassifier([2, 2])
    x = np.array([[1.0, 2.0, 3.0]])
    softmax = model.softmax(x)
    assert np.allclose(softmax.sum(), 1.0, atol=1e-5), "Softmax output does not sum to 1"
    print("✓ test_softmax_output passed.")


def test_sigmoid_range():
    model = MLPClassifier([1, 1])
    x = np.linspace(-10, 10, 100)
    y = model.sigmoid(x)
    assert np.all((y >= 0) & (y <= 1)), "Sigmoid output not in [0, 1]"
    print("✓ test_sigmoid_range passed.")


def test_predict_proba_and_predict_shapes():
    model = MLPClassifier([4, 5, 2], random_seed=42)
    model._initialize_weights()
    X = np.random.randn(5, 4)
    proba = model.predict_proba(X)
    pred = model.predict(X)
    assert proba.shape == (5, 2), f"Expected proba shape (5, 2), got {proba.shape}"
    assert pred.shape == (5,), f"Expected pred shape (5,), got {pred.shape}"
    print("✓ test_predict_proba_and_predict_shapes passed.")


def test_cost_nonnegative():
    model = MLPClassifier([4, 5, 2], random_seed=42)
    model._initialize_weights()
    X = np.random.randn(5, 4)
    y = np.array([0, 1, 0, 1, 1])
    y_onehot = np.eye(2)[y]
    y_pred = model.predict_proba(X)
    cost = model.calculate_cost(y_onehot, y_pred)
    assert cost >= 0.0, f"Cost should be non-negative, got {cost}"
    print("✓ test_cost_nonnegative passed.")


print("\nRunning MLPClassifier tests...\n")
for test in [
    test_weight_initialization_shapes, test_forward_pass_output_shape,
    test_softmax_output, test_sigmoid_range, test_predict_proba_and_predict_shapes,
    test_cost_nonnegative,
]:
    try:
        test()
    except Exception as e:
        print(f"Error during testing - test: {test} error: {e}")
# Out:
# Running MLPClassifier tests...
#
# ✓ test_weight_initialization_shapes passed.
# ✓ test_forward_pass_output_shape passed.
# ✓ test_softmax_output passed.
# ✓ test_sigmoid_range passed.
# ✓ test_predict_proba_and_predict_shapes passed.
# ✓ test_cost_nonnegative passed.

# %% [markdown]
# Zeige nun noch anhand des kleinen Entwicklungsdatensatzes (`dev_data.csv`), dass deine Implementierung funktioniert, indem du die Output-Variable $y \in \{0, 1, 2\}$ anhand der Input-Variablen $\mathbf{x} = \left(x_1, x_2\right)$ vorhersagen kannst.
# Erzeuge dazu ein Netzwerk mit 2 Hidden Layern mit je 20 Units/Nodes plus Bias Unit und optimiere die Modell-Koeffizienten.
#
# Zeichne
#
# - die Entwicklung der Kostenfunktion über das Gradient Descent Verfahren hinweg
# - die Confusion Matrix
# - die Decision Regions mit `mlxtend.plotting.plot_decision_regions`
#
#
# und berechne die Overall Accuracy auf dem Entwicklungsdatensatz.
#
# Diskutiere deine Einsichten.

# %%
import pandas as pd
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score
from mlxtend.plotting import plot_decision_regions

data = pd.read_csv("dev_data.csv")
X = data[["x1", "x2"]].values
y = data["y"].values

mlp = MLPClassifier(
    num_nodes_per_layer=[2, 20, 20, 3],
    lr=0.1,
    alpha=0.001,
    max_num_steps=1000,
    batch_size=None,
    weights_init_range=(-0.1, 0.1),
    adaptive_lr_constant=1e-3,
)

mlp.fit(X, y)

plt.plot(mlp.loss_curve_)
plt.title("Kostenfunktion über Trainingsschritte")
plt.xlabel("Schritt")
plt.ylabel("Kosten")
plt.grid(True)
plt.show()

y_pred = mlp.predict(X)
cm = confusion_matrix(y, y_pred)

sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Vorhergesagt")
plt.ylabel("Tatsächlich")
plt.show()

accuracy = accuracy_score(y, y_pred)
print(f"Overall Accuracy: {accuracy:.2f}")

plot_decision_regions(X, y.astype(np.int_), clf=mlp)
plt.title("Decision Regions")
plt.xlabel("x1")
plt.ylabel("x2")
plt.show()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# MLPClassifier(adaptive_lr_constant=0.001, alpha=0.001, lr=0.1,
#               num_nodes_per_layer=[2, 20, 20, 3],
#               weights_init_range=(-0.1, 0.1))
# Text(0.5, 1.0, 'Kostenfunktion über Trainingsschritte')
# Text(0.5, 0, 'Schritt')
# Text(0, 0.5, 'Kosten')
# <Axes: >
# Text(0.5, 1.0, 'Confusion Matrix')
# Text(0.5, 23.52222222222222, 'Vorhergesagt')
# Text(50.722222222222214, 0.5, 'Tatsächlich')
# Overall Accuracy: 0.61
# <Axes: >
# Text(0.5, 1.0, 'Decision Regions')
# Text(0.5, 0, 'x1')
# Text(0, 0.5, 'x2')

# %% [markdown]
# Interpretiere das Ergebnis.

# %% [markdown]
# ### Kostenfunktion (Training Loss)
# - Kostenfunktion sinkt stetig über 1000 Schritte hinweg.
# - Besonders starker Abfall nach ca. 800 Schritten.
# - Keine Anzeichen für Divergenz oder Overfitting.
# - Adaptive Lernrate scheint gut zu funktionieren.
#
# ### Confusion Matrix
# - **Klasse 2:** Sehr gute Erkennungsrate (99 von 100 korrekt).
# - **Klasse 0:** Mehrheit korrekt erkannt (71 korrekt), aber 23 fälschlich als Klasse 2.
# - **Klasse 1:** Wird am häufigsten falsch klassifiziert.
#   - 72-mal fälschlich als Klasse 0 erkannt.
#   - Deutliche Schwächen bei der Trennung von Klasse 0 und 1.
#
# ### Decision Regions
# - **Klasse 2:** Klar abgegrenzt (rechts unten im Merkmalsraum).
# - Starke Überlappung zwischen **Klasse 0** und **1**.
# - Entscheidungslinien zwischen Klasse 0 und 1 verlaufen diffus – keine klaren Grenzen.

# %% [markdown]
# ## Aufgabe 8 (10 Punkte)
#
# In dieser Aufgabe wirst du deine MLP-Implementierung verwenden, um ein Modell für die Vorhersage der (rohen, nicht-transformierten) Postleitzahlziffern zu entwickeln.
#
# Dazu sollst du die Daten prä-prozessieren (_pre-processing_), sodass diese optimal für die Modellierung verwendet werden können. Und du sollst verschiedene Modelle entwickeln und das beste im Sinne der Overall Accuracy mit einem geeigneten Verfahren auswählen. Gib die Overall Accuracy auf dem Testset aus.
#
# Zeichne die Confusion Matrix, deines besten Modells auf dem Testset.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score

# 1. Eingabedaten vorbereiten (Subset: 10'000 Training, 2'000 Test)
x_train_small = x_train[:10000].reshape(10000, -1)
y_train_small = y_train[:10000]
x_test_small = x_test[:2000].reshape(2000, -1)
y_test_small = y_test[:2000]

# 2. Skalieren
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train_small)
x_test_scaled = scaler.transform(x_test_small)

# 3. Verschiedene Netzarchitekturen definieren
architectures = [
    [128, 64, 10],
    [256, 128, 10],
    [128, 128, 64, 10]
]

best_model = None
best_accuracy = 0
best_architecture = None

# 4. Modelle trainieren und Accuracy vergleichen
for arch in architectures:
    print(f"Training mit Architektur: {arch}")
    model = MLPClassifier(
        num_nodes_per_layer=[x_train_scaled.shape[1]] + arch,
        lr=0.1,
        alpha=0.001,
        max_num_steps=1000,
        batch_size=64,
        weights_init_range=(-0.1, 0.1),
        adaptive_lr_constant=1e-3
    )
    model.fit(x_train_scaled, y_train_small)
    acc = model.score(x_test_scaled, y_test_small)
    print(f"Test Accuracy: {acc:.4f}\n")

    if acc > best_accuracy:
        best_model = model
        best_accuracy = acc
        best_architecture = arch

# 5. Beste Architektur und Accuracy
print(f"Beste Architektur: {best_architecture}")
print(f"Overall Accuracy auf Testset: {best_accuracy:.4f}")

# 6. Confusion Matrix
y_pred = best_model.predict(x_test_scaled)
cm = confusion_matrix(y_test_small, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix des besten MLP-Modells auf dem Testset")
plt.xlabel("Vorhergesagte Klasse")
plt.ylabel("Tatsächliche Klasse")
plt.tight_layout()
plt.show()
# Out:
# Training mit Architektur: [128, 64, 10]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# MLPClassifier(adaptive_lr_constant=0.001, alpha=0.001, batch_size=64, lr=0.1,
#               num_nodes_per_layer=[784, 128, 64, 10],
#               weights_init_range=(-0.1, 0.1))
# Test Accuracy: 0.7675
#
# Training mit Architektur: [256, 128, 10]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# MLPClassifier(adaptive_lr_constant=0.001, alpha=0.001, batch_size=64, lr=0.1,
#               num_nodes_per_layer=[784, 256, 128, 10],
#               weights_init_range=(-0.1, 0.1))
# Test Accuracy: 0.8460
#
# Training mit Architektur: [128, 128, 64, 10]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# MLPClassifier(adaptive_lr_constant=0.001, alpha=0.001, batch_size=64, lr=0.1,
#               num_nodes_per_layer=[784, 128, 128, 64, 10],
#               weights_init_range=(-0.1, 0.1))
# Test Accuracy: 0.1185
#
# Beste Architektur: [256, 128, 10]
# Overall Accuracy auf Testset: 0.8460
# <Axes: >
# ...

# %% [markdown]
# Erkläre dein Vorgehen und diskutiere die Resultate. Vergleiche sie mit denjenigen der logistischen Regression.
#
# (Es folgt eine Textantwortzelle. Nicht löschen.)

# %% [markdown]
# ## Vorgehen
#
# - Die Bilddaten wurden auf 10'000 Trainings- und 2'000 Testbeispiele reduziert, um Speicherprobleme zu vermeiden.
# - Die Bilder (28×28) wurden zu Vektoren (784-dimensionale Feature-Vektoren) umgeformt.
# - Anschliessend wurden die Eingabedaten mit `StandardScaler` normalisiert.
# - Es wurden drei verschiedene MLP-Architekturen getestet:
#   - `[128, 64, 10]`
#   - `[256, 128, 10]`
#   - `[128, 128, 64, 10]`
# - Jedes Modell wurde für 1'000 Schritte mit Mini-Batch-Grösse 64 trainiert.
# - Das Modell mit der höchsten Genauigkeit auf dem Testset wurde ausgewählt.
#
# ## Resultate
#
# - Die Architektur `[256, 128, 10]` erzielte die beste Testgenauigkeit mit **0.8460**.
# - Die anderen Architekturen schnitten wie folgt ab:
#   - `[128, 64, 10]`: **0.7675**
#   - `[128, 128, 64, 10]`: **0.1185** (deutlich schlechter, vermutlich durch schlechte Gewichtsinitialisierung oder Überanpassung)
# - Die Confusion Matrix zeigt eine insgesamt gute Klassifikationsleistung:
#   - Klasse **1** und **4** wurden sehr zuverlässig erkannt.
#   - Klasse **5**, **8** und **9** zeigten häufiger Fehlklassifikationen.
#   - Verwechslungen treten vor allem bei ähnlich geformten Ziffern auf (z. B. **3 & 8**, **5 & 6**, **9 & 4**).
